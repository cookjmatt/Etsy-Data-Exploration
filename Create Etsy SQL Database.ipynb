# %% [markdown]
# Mon 9/17/18 Creating SQL database from Etsy data

# %%
import pandas as pd
import json
from glob import glob
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2
pd.set_option('display.max_columns', 50)

# %%
cd ~/Documents/Insight/Etsy/180912_1st_Exploratory_Data_Analysis/
# Out:
# /home/mc/Documents/Insight/Etsy/180912_1st_Exploratory_Data_Analysis

# %%
with open('listings/0001.json', 'r') as listings_file:
    etsy_df = pd.read_json(listings_file)

# %% [markdown]
# Create dataframes for each table in the dataset
#     1. listings table
#     2. tags table
#     3. materials table
#     4. categories table
#     5. category ids table
#     6. styles table

# %%
# 1. main product table
column_names = ['listing_id','user_id','category_id','shop_section_id','price','currency_code','views','num_favorers','title','url','quantity','featured_rank','recipient','occasion','when_made','who_made','has_variations','is_customizable','is_digital','is_private','is_supply','language','original_creation_tsz','creation_tsz','ending_tsz','last_modified_tsz','state_tsz','processing_min','processing_max','state','non_taxable']
listings = etsy_df[column_names].copy(deep=True)

# 2. tags table
tags = etsy_df[['listing_id','tags']].copy(deep=True).set_index('listing_id').tags.apply(pd.Series).stack().reset_index(level=-1, drop=True).astype(str).reset_index().rename(index=str, columns={0: "tag"})

# 3. materials table
materials = etsy_df[['listing_id','materials']].copy(deep=True).set_index('listing_id').materials.apply(pd.Series).stack().reset_index(level=-1, drop=True).astype(str).reset_index().rename(index=str, columns={0: "material"})

# 4. categories table
categories = etsy_df[['listing_id','category_path']].copy(deep=True).set_index('listing_id').category_path.apply(pd.Series).stack().reset_index(level=-1, drop=True).astype(str).reset_index().rename(index=str, columns={0: "category"})

# 5. category ids table
category_ids = etsy_df[['listing_id','category_path_ids']].copy(deep=True).set_index('listing_id').category_path_ids.apply(pd.Series).stack().reset_index(level=-1, drop=True).astype(int).reset_index().rename(index=str, columns={0: "category_id"})

# 6. styles table
# NOTE: "style" is a keyword in pandas, so the the column name has to be changed to "styles" first
styles = etsy_df[['listing_id','style']].copy(deep=True)
styles = styles.rename(index=str, columns={"style": "styles"})
styles = styles.set_index('listing_id').styles.apply(pd.Series).stack().reset_index(level=-1, drop=True).astype(str).reset_index().rename(index=str, columns={0: "style"})

table_list = [listings, tags, materials, categories, category_ids, styles]

# %%
listings
# Out:
#       listing_id   user_id  category_id  shop_section_id   price  \
# 0      101000405  20198008     68902992       11235567.0   14.50
# 1      101000518  14657489     68907858       11797420.0   12.00
# 2      101000649  20823487     69153339       13025088.0   15.99
# 3      101000651  19354077     68889592       11668909.0    5.00
# 4      101000721   7116046     68902452        6381199.0   10.00
# 5      101000734   8466169     68925824        6560153.0   30.00
# 6      101000758  21245871     68918698       11492360.0   18.00
# 7      101001157  16360331     68897044       14356960.0    9.95
# 8      101001245   5312557     69173677        5732269.0   19.99
# 9      101001303   8466169     68925824        6560153.0   30.00
# 10     101001487  19407356     69176515       11086022.0    6.00
# 11     101001518  16532211     69177627       11586819.0    9.00
# 12     101001806  19354077     68889592       11668909.0    4.00
# 13     101001836   8312095     68888634        6530560.0   45.95
# 14     101001945  10681130     69172099        7260952.0    6.25
# 15     101002054  16860340     68890428       11001777.0    5.00
# ...            ...    ...           ...
# 9970           USD    246            17
# 9971           USD   5964           330
# 9972           USD   5454           121
# 9973           USD    140           148
# 9974           USD    836            21
# 9975           USD    378            12
# 9976           USD    137            16
# 9977           USD    100           109
# 9978           USD   1513           204
# 9979           USD    114            66
# 9980           USD   1035            21
# 9981           USD   2582           429
# 9982           USD     44             1
# 9983           USD   4266           356
# 9984           USD     34             2
# 9985           USD   3373          1062
# 9986           USD    596            26
# 9987           USD    224            11
# 9988           USD   1931           139
# 9989           USD     35             4
# 9990           USD   5346           221
# 9991           USD    200            10
# 9992           USD     81             4
# 9993           USD     63            17
# 9994           USD    944            77
# 9995           CAD   1248           133
# 9996           GBP     80            14
# 9997           USD    210            13
# 9998           USD    208             6
# 9999           USD    181             3
#
#                                                   title  \
# 0     Little Reversible Dress in Brown Flower and Pu...
# 1     Pollux Pendant -Beading Pattern/Tutorial - PDF...
# 2     Pet Collar Tags Personalized - Dog Bow Tie Las...
# 3                                              Red Rose
# 4                                         Brachiosaurus
# 5     Speak your truth Soulful Yoga Plow Pose artwor...
# 6     Personalized Name and Monogram Vinyl Decal- Gi...
# 7     Felted Bird brooch with Beads and Sequins  - F...
# 8     Owl with Letters Custom Return Address Rubber ...
# 9     The Universe will Rally Soulful Yoga Plow Pose...
# 10    1 oz Midnight Forest Black Tea - Elderberry te...
# 11    PSYCHE Lip Gloss: 10 mL Tube, Lavender Pink Sh...
# 12                                 Gamecocks Small Rose
# 13    Personalized brown zebra diaper bag with pink ...
# 14    School Bus - KONA solids from Robert Kaufman -...
# 15                             Bumble Bee Baby Bracelet
# 16    Crochet Baby Girl Newborn  Flower Headband Str...
# 17                                 Gamecocks Small Rose
# 18                                    Salt mill, cherry
# 19                                   Clemson Small Rose
# 20    Large giraffe wall stencil, giraffe wall stenc...
# 21    Sibling Monkey Shirt Set, Set of Four, Biggest...
# 22           KIT Dazzling Dome Ring Red and Pink Colors
# 23    One Decade Rosary - Turquoise, San Damiano, Ho...
# 24                                   Clemson Small Rose
# 25    Pretty Soldier Sailor Moon Pillow -- Sailor Ch...
# 26    Calla lily buttonhole boutonnière brooch groom...
# 27                                      Blue Small Rose
# 28    Tatted Sterling Daisy Bobby Pin in Victorian R...
# 29    Buttercup - KONA solids from Robert Kaufman - ...
# ...                                                 ...
# 9970  Hand painted personalized 5X7 girls pink cross...
# 9971  Super Awesome Diaper Bag - CUSTOMIZABLE - Ever...
# 9972                       Black Steampunk Holster Bags
# 9973  Downton Abbey type Pillow of 1920&#39;s  Lady ...
# 9974  SOLD - Handcrafted Large Industrial Rustic Bar...
# 9975  Kindle Fire or Kindle Fire HD 7&quot; 2012 mod...
# 9976  Amy Butler Fabric Cosmetic Bag Wristlet Clutch...
# 9977  Downton Abbey Type 1920&#39;s  Lady with Car P...
# 9978  Organic Mud Mask // Single-use Mud Mask // Fre...
# 9979     Fairy Pillow 10 x 6 from Vintage Ad   Handmade
# 9980  SOLD - Handmade Large Industrial Rustic Barnwo...
# 9981                               Large Porcelain Bell
# 9982  Hand Crafted - UNIQUE - OOAK - Summer Dress fo...
# 9975  https://www.etsy.com/listing/102058416/kindle-...        15
# 9976  https://www.etsy.com/listing/102058470/amy-but...         1
# 9977  https://www.etsy.com/listing/102058484/downton...         9
# 9978  https://www.etsy.com/listing/102058564/organic...       240
# 9979  https://www.etsy.com/listing/102058760/fairy-p...         7
# 9980  https://www.etsy.com/listing/102058898/sold-ha...         1
# 9981  https://www.etsy.com/listing/102058968/large-p...         4
# 9982  https://www.etsy.com/listing/102059061/hand-cr...         1
# 9983  https://www.etsy.com/listing/102059125/cotton-...        26
# 9984  https://www.etsy.com/listing/102059263/barely-...         1
# 9985  https://www.etsy.com/listing/102059269/small-p...         9
# 9986  https://www.etsy.com/listing/102059304/bamboo-...        44
# 9987  https://www.etsy.com/listing/102059466/kindle-...        19
# 9988  https://www.etsy.com/listing/102059602/formal-...         1
# 9989  https://www.etsy.com/listing/102059611/natural...         1
# 9990  https://www.etsy.com/listing/102059826/madelyn...         7
# 9991  https://www.etsy.com/listing/102059973/hand-pa...         6
# 9992  https://www.etsy.com/listing/102060013/the-per...         1
# 9993  https://www.etsy.com/listing/102060080/large-c...         1
# 9994  https://www.etsy.com/listing/102060082/car-saf...         4
# 9995  https://www.etsy.com/listing/102060195/miniatu...         1
# 9996  https://www.etsy.com/listing/102060251/leaf-pr...         1
# 9997  https://www.etsy.com/listing/102060338/backpac...         1
# 9998  https://www.etsy.com/listing/102060467/kindle-...        19
# 9999  https://www.etsy.com/listing/102060491/kindle-...        19
#
#       featured_rank      recipient  occasion      when_made      who_made  \
# 0               NaN           None      None      2010_2014         i_did
# 1               NaN           None      None      2010_2014         i_did
# 2               NaN           pets      None  made_to_order         i_did
# 3               NaN          women      None      2010_2014         i_did
# 4               NaN       children      None      2010_2014         i_did
# 5               NaN  unisex_adults      None      2010_2014         i_did
# 6               NaN           None      None  made_to_order         i_did
# 7               NaN          women  july_4th      2010_2014         i_did
# 8               NaN           None      None  made_to_order         i_did
# 9               NaN  unisex_adults      None      2010_2014         i_did
# 10              NaN           None      None      2010_2014         i_did
# 11              NaN           None      None      2010_2014         i_did
# 12              NaN          women      None      2010_2014         i_did
# 13              NaN         babies  new_baby  made_to_order         i_did
# 14              NaN           None      None      2010_2014  someone_else
# 15              NaN     baby_girls      None      2010_2014         i_did
# 16              NaN     baby_girls  new_baby  made_to_order         i_did
# 17              NaN          women      None      2010_2014         i_did
# 18              NaN           None      None      2010_2015         i_did
# 19              NaN          women      None      2010_2014         i_did
# 20              NaN           None      None  made_to_order         i_did
# 21              NaN           None  new_baby  made_to_order         i_did
# 22              NaN           None      None      2010_2014         i_did
# 23              NaN           None      None      2010_2014         i_did
# 24              NaN          women      None      2010_2014         i_did
# 25              NaN           None      None  made_to_order         i_did
# 26              NaN           None      None  made_to_order         i_did
# 27              NaN          women      None      2010_2014         i_did
# 28              NaN           None      None      2010_2014         i_did
# 29              NaN           None      None      2010_2014  someone_else
# ...             ...            ...       ...            ...           ...
# 9970            NaN          girls      None  made_to_order         i_did
# 9971            NaN           None      None      2010_2014         i_did
# 9972            1.0  unisex_adults      None  made_to_order         i_did
# 9973            NaN           None      None  made_to_order         i_did
# 9974            3.0           None      None      2010_2014         i_did
# 9975            NaN           None      None  made_to_order         i_did
# 9976            NaN          women      None  made_to_order         i_did
# 9977            NaN           None      None  made_to_order         i_did
# 9978            NaN  unisex_adults   wedding      2010_2014         i_did
# 9979            NaN           None      None  made_to_order         i_did
# 9980            NaN           None      None      2010_2014         i_did
# 9981            NaN           None      None      2010_2014         i_did
# 9982            NaN           None      None      2010_2014         i_did
# 9983            NaN  unisex_adults   wedding      2010_2014         i_did
# 9984            NaN           None      None      2010_2014         i_did
# 9985            NaN           None      None      2010_2014         i_did
# 9986            NaN           None      None      2010_2014         i_did
# 9987            NaN           None      None  made_to_order         i_did
# 9988            NaN           pets   wedding  made_to_order         i_did
# 9989            NaN           None      None  made_to_order         i_did
# 9990            1.0          women  new_baby      2010_2014         i_did
# 9991            NaN           boys   baptism  made_to_order         i_did
# 9992            4.0           None      None      2010_2014         i_did
# 9993            NaN       children      None      2010_2014         i_did
# 9994            NaN           pets      None      2010_2014         i_did
# 9995            NaN           None      None  made_to_order         i_did
# 9996            NaN           None      None      2010_2014         i_did
# 9997            NaN           None      None      2010_2014         i_did
# 9998            NaN           None      None  made_to_order         i_did
# 9999            NaN           None      None  made_to_order         i_did
#
#       has_variations  is_customizable  is_digital  is_private is_supply  \
# 0               True             True       False       False     false
# 1              False            False        True       False      true
# 2              False            False       False       False     false
# 3              False             True       False       False     false
# 4              False             True       False       False     false
# 5              False             True       False       False     false
# 6               True             True       False       False     false
# 7              False             True       False       False     false
# 8               True             True       False       False     false
# 9              False             True       False       False     false
# 10             False             True       False       False     false
# 11             False            False       False       False     false
# 12             False             True       False       False     false
# 13             False             True       False       False     false
# 14             False            False       False       False      true
# 15             False             True       False       False     false
# 16             False             True       False       False     false
# 17             False             True       False       False     false
# 18             False            False       False       False     false
# 19             False             True       False       False     false
# 20             False             True       False       False     false
# 21              True             True       False       False     false
# 22             False            False       False       False      true
# 23             False             True       False       False     false
# 24             False             True       False       False     false
# 25             False             True       False       False     false
# 26             False             True       False       False     false
# 27             False             True       False       False     false
# 28             False             True       False       False     false
# 29             False            False       False       False      true
# ...              ...              ...         ...         ...       ...
# 9970           False             True       False       False     false
# 9971            True             True       False       False     false
# 9972           False             True       False       False     false
# 9973           False            False       False       False     false
# 9974           False            False       False       False     false
# 9975           False             True       False       False     false
# 9976           False            False       False       False     false
# 9977           False            False       False       False     false
# 9978           False            False       False       False     false
# 9979           False            False       False       False     false
# 9980           False            False       False       False     false
# 9981            True             True       False       False     false
# 9982           False             True       False       False     false
# 9983           False            False       False       False     false
# 9984           False            False       False       False     false
# 9985            True             True       False       False     false
# 9986           False            False        True       False     false
# 9987           False             True       False       False     false
# 9988            True             True       False       False     false
# 9989           False             True       False       False     false
# 9990            True             True       False       False     false
# 9991           False             True       False       False     false
# 9992           False             True       False       False     false
# 9993           False             True       False       False     false
# 9994            True             True       False       False     false
# 9995           False            False       False       False     false
# 9996           False            False       False       False     false
# 9997           False            False       False       False     false
# 1            1405107171  1405100435             NaN             NaN  active
# 2            1412182570  1368754108             NaN             NaN  active
# 3            1413312965  1413312643             1.0             2.0  active
# 4            1411676367  1389997787             NaN             NaN  active
# 5            1411734838  1400031030             NaN             NaN  active
# 6            1413548399  1411594946             1.0             3.0  active
# 7            1407590177  1403373635             NaN             NaN  active
# 8            1411855712  1401945619             NaN             NaN  active
# 9            1412867523  1392496833             NaN             NaN  active
# 10           1411259051  1362118222            10.0            15.0  active
# 11           1412906164  1412903395             7.0             8.0  active
# 12           1413313053  1413312639             1.0             2.0  active
# 13           1412979319  1412978638             NaN             NaN  active
# 14           1412616700  1408113631             1.0             3.0  active
# 15           1414023653  1413860432             NaN             NaN  active
# 16           1411474604  1408827042            10.0            15.0  active
# 17           1413312832  1413312640             NaN             NaN  active
# 18           1427310433  1410149754             1.0             3.0  active
# 19           1413313031  1413312640             1.0             2.0  active
# 20           1412436193  1412428174             3.0             5.0  active
# 21           1412890174  1359839777             1.0             3.0  active
# 22           1413807510  1377141467             1.0             1.0  active
# 23           1412907319  1403400005             1.0             3.0  active
# 24           1413313002  1413312641             1.0             2.0  active
# 25           1409746087  1404516634             5.0            10.0  active
# 26           1412427533  1402601952             NaN             NaN  active
# 27           1413312937  1413312643             1.0             2.0  active
# 28           1409272230  1405358528             5.0             7.0  active
# 29           1412616700  1408113631             1.0             3.0  active
# ...                 ...         ...             ...             ...     ...
# 9970         1410874553  1401228664            20.0            30.0  active
# 9971         1409352085  1409075737            10.0            15.0  active
# 9972         1411861413  1410060894            10.0            15.0  active
# 9973         1412876148  1412497829             1.0             2.0  active
# 9974         1412516044  1407264045             NaN             NaN  active
# 9975         1406152049  1405958428             1.0             3.0  active
# 9976         1413234463  1412647361             1.0             3.0  active
# 9977         1412876147  1412497833             1.0             2.0  active
# 9978         1409097080  1400168429             NaN             NaN  active
# 9979         1412876147  1412497834             1.0             2.0  active
# 9980         1407590284  1404308423             NaN             NaN  active
# 9981         1408370548  1401829228             NaN             NaN  active
# 9982         1412003609  1411904432             NaN             NaN  active
# 9983         1412006873  1411868184             3.0             5.0  active
# 9984         1405202580  1400098229             NaN             NaN  active
# 9985         1413291563  1413148248             5.0            10.0  active
# 9986         1412177986  1412177882             NaN             NaN  active
# 9987         1409085516  1409076634             1.0             3.0  active
# 9988         1413422253  1413422231             NaN             NaN  active
# 9989         1403808275  1403356819             NaN             NaN  active
# 9990         1413756358  1410385386             3.0             5.0  active
# 9991         1411797419  1404581432            20.0            30.0  active
# 9992         1413428328  1408722401             NaN             NaN  active
# 9993         1412090331  1412019662             1.0             1.0  active
# 9994         1411936038  1403430684             NaN             NaN  active
# 9995         1413119609  1412540430            10.0            15.0  active
# 9996         1411652756  1411407958             NaN             NaN  active
# 9997         1413034828  1380891957             1.0             2.0  active
# 9998         1407868140  1407773429             1.0             3.0  active
# 9999         1406053877  1405958426             1.0             3.0  active
#
#       non_taxable
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29          False
# ...           ...
# 9970        False
# 9971        False
# 9972        False
# 9973        False
# 9974        False
# 9975        False
# 9976        False
# 9977        False
# 9978        False
# 9979        False
# 9980        False
# 9981        False
# 9982        False
# 9983        False
# 9984        False
# 9985        False
# 9986        False
# 9987        False
# 9988        False
# 9989        False
# 9990         True
# 9991        False
# 9992        False
# 9993        False
# 9994        False
# 9995        False
# 9996        False
# 9997         True
# 9998        False
# 9999        False
#
# [10000 rows x 31 columns]

# %%
to_int_list = ['user_id','category_id','shop_section_id','views','num_favorers','quantity','featured_rank','has_variations','is_customizable','is_digital','is_private','original_creation_tsz','ending_tsz','last_modified_tsz','state_tsz','processing_min','processing_max','non_taxable']
listings[to_int_list] = listings[to_int_list].astype(float)

# %%
listings.
# Out:
# listing_id                 int64
# user_id                  float64
# category_id              float64
# shop_section_id          float64
# price                    float64
# currency_code             object
# views                    float64
# num_favorers             float64
# title                     object
# url                       object
# quantity                 float64
# featured_rank            float64
# recipient                 object
# occasion                  object
# when_made                 object
# who_made                  object
# has_variations           float64
# is_customizable          float64
# is_digital               float64
# is_private               float64
# is_supply                 object
# language                  object
# original_creation_tsz    float64
# creation_tsz               int64
# ending_tsz               float64
# last_modified_tsz        float64
# state_tsz                float64
# processing_min           float64
# processing_max           float64
# state                     object
# non_taxable              float64
# dtype: object

# %% [markdown]
# Create Etsy Database

# %%
# Define a database name (etsy)
# Set your postgres username/password, and connection specifics
username = 'postgres'
password = 'jlmlcook'
host     = 'localhost'
port     = '5432'
db_name  = 'etsy'

# %%
## 'engine' is a connection to a database
## Here, we're using postgres, but sqlalchemy can connect to other things too.
engine = create_engine( 'postgresql://{}:{}@{}:{}/{}'.format(username, password, host, port, db_name) )
print(engine.url)

# %%
## create a database (if it doesn't exist)
if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))

# %%
## insert data into database from Python (proof of concept - this won't be useful for big data, of course)
listings.to_sql("listings", engine, index=False, if_exists='append')
tags.to_sql("tags", engine, index=False, if_exists='append')
materials.to_sql("materials", engine, index=False, if_exists='append')
categories.to_sql("categories", engine, index=False, if_exists='append')
category_ids.to_sql("category_ids", engine, index=False, if_exists='append')
styles.to_sql("styles", engine, index=False, if_exists='append')

with engine.connect() as con:
    con.execute('ALTER TABLE listings ADD PRIMARY KEY (listing_id);')

# %%
# Connect to make queries using psycopg2
con = None
con = psycopg2.connect(user = username, password = password, host = host, port = port, database = db_name)

# %%
# query:
sql_query = """
SELECT COUNT(listing_id) FROM listings;
"""
test = pd.read_sql_query(sql_query,con)
print(pd.read_sql_query(sql_query,con))
# Out:
#    count
# 0  20000

# %%
print(test['count'][0])
# Out:
# 20000

# %%
# query:
sql_query = """
SELECT * FROM products_table;
"""

products2 = pd.read_sql_query(sql_query,con)

# %%
file_list = sorted(glob('listings/*.json'))
file_list = ['listings/0000.json']
for i in range(len(file_list)):
    print(file_list[i])
